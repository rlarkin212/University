# %% [markdown]
# # Notebook 2

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Line Graph showing the amount of anti social behaviour recorded between 10/2014 - 04/2017

# %%
dfAllAsbByDate = pd.read_csv(r'C:\Users\rlark\Documents\Uni\Final Year\CSC3062- Data Visualisation\Final Notebook\DataSets\AntiSocialBehaviourByDate.csv', encoding = 'ISO-8859-1', error_bad_lines=False)
dfAllAsbByDate.drop(['Unnamed: 0'], axis=1, inplace=True)
lineChartAmountByMonth = dfAllAsbByDate.set_index('Date').plot(rot=90, kind='line', figsize=(15,8), grid=True
                                ,title="Amount Of Anti-Social Behaviour Recorded Between 10/2014 - 04/2017", color=['#9842f4'])
lineChartAmountByMonth.set_xlabel("Date",fontsize=12)
lineChartAmountByMonth.set_ylabel("Amount Of Recorded Anti-Social Behaviour",fontsize=12)
# Out:
# Text(0,0.5,u'Amount Of Recorded Anti-Social Behaviour')

# %% [markdown]
# ### Explination of Trends
# Above shows a line graph for all recorded anti social behaviour recorded between 10/2014 and 04/2017
# ​
# The graph follows a trend that would be expected:
# * The amount rises in the times of the 12th, Halloween, St. Patricks Day and New Years Eve
# * However every year the amount of anti social behaviour falls to an all year low during December
#  * One reason for this could be that youths are in door playing with christmas presents and spending time with relatives
#  * Another reason could be that the amount of on patrol police officers is fewer at this time meaning anti-behaviour goes un noticed

# %% [markdown]
# ## Bar chart showing the amount of antisocial behaviour recorded by area (2500 sample)

# %%
dfAsbByArea = pd.read_csv(r'C:\Users\rlark\Documents\Uni\Final Year\CSC3062- Data Visualisation\Final Notebook\DataSets\ASBCorrectArea.csv', encoding = 'ISO-8859-1', error_bad_lines=False)
dfAsbByArea.drop(['Unnamed: 0'], axis=1, inplace=True)
barchartByArea = dfAsbByArea.set_index('AdministrativeAreaLevel2').plot(rot=90, kind='bar', figsize=(15,8), grid=True
                                ,title="Amount Of Anti-Social Behaviour By Area", color=['g'])
barchartByArea.set_xlabel("Area",fontsize=12)
barchartByArea.set_ylabel("Amount Of Recorded Anti-Social Behaviour",fontsize=12)
# Out:
# Text(0,0.5,u'Amount Of Recorded Anti-Social Behaviour')

# %% [markdown]
# ### Explainin Antisocial Behaviour bar chart
#
#
# ### Below is a heat map showing the density of recorded antisocial behaviour

# %% [markdown]
# ![AntiSocial%20Behaviour%20HeatMap.png](attachment:AntiSocial%20Behaviour%20HeatMap.png)

# %% [markdown]
# ## Bar chart showing the amount of youth clubs in each area (2500 sample)

# %%
dfYouthClubsByArea = pd.read_csv(r'C:\Users\rlark\Documents\Uni\Final Year\CSC3062- Data Visualisation\Final Notebook\DataSets\YouthClubs.csv', encoding = 'ISO-8859-1', error_bad_lines=False)
dfYouthClubsByArea.drop(['Unnamed: 0'], axis=1, inplace=True)
barChartArea = dfYouthClubsByArea.set_index('AdministrativeAreaLevel2').plot(rot=90, kind='bar', figsize=(15,8), grid=True
                                ,title="Amount Of Youth Clubs By Area", color=['#F9746A'])
barChartArea.set_xlabel("Area",fontsize=12)
barChartArea.set_ylabel("Amount Of Youth Clubs",fontsize=12)
# Out:
# Text(0,0.5,u'Amount Of Youth Clubs')

# %% [markdown]
# ### Explain Youth Club bar chart

# %% [markdown]
# ## Below shows the correlation between the amount anti social behaviour in an area and the amount of youth clubs in an area

# %%
dfAntiSocial_YouthClubs = pd.read_csv(r'C:\Users\rlark\Documents\Uni\Final Year\CSC3062- Data Visualisation\Final Notebook\DataSets\AntiSocialBehaviour_YouthClubs.csv', encoding = 'ISO-8859-1', error_bad_lines=False)
dfAntiSocial_YouthClubs.drop(['Unnamed: 0'], axis=1, inplace=True)
sns.lmplot(x='AS Behaviour Amount',y='YC Amount',data=dfAntiSocial_YouthClubs.corr(),fit_reg=True)

# %%
pd.plotting.scatter_matrix(dfAntiSocial_YouthClubs.corr(), alpha = 1.0, color=['#000000'], s=300, figsize = (8,8), diagonal = 'kde');

# %% [markdown]
# ### Explaining Correlation

# %% [markdown]
# ## Below shows the amount of people processed by the Youth Justice Stystem by Area Between 2014 - 2017

# %%
dfYJS = pd.read_csv(r'C:\Users\rlark\Documents\Uni\Final Year\CSC3062- Data Visualisation\Final Notebook\DataSets\YouthJusticeService\YJS.csv', encoding = 'ISO-8859-1')
barChartArea = dfYJS.set_index('Area').plot(rot=90, kind='bar', figsize=(15,8), grid=True
                                ,title="Amount Of People Processed By The Youth Justice Area By Area", color=['#00BEC5'])
barChartArea.set_xlabel("Area",fontsize=12)
barChartArea.set_ylabel("Amount Processed",fontsize=12)
# Out:
# Text(0,0.5,u'Amount Processed')

# %% [markdown]
# ### Explaining YJS Trends

# %% [markdown]
# ## Below shows the correlation between the amount of Anti Social Behaviour in an area and the amount of people processed by the Youth Justice System  in an area

# %%
dfAntiSocial_YJS = pd.read_csv(r'C:\Users\rlark\Documents\Uni\Final Year\CSC3062- Data Visualisation\Final Notebook\DataSets\AntiSocialBehaviour_YJS.csv', encoding = 'ISO-8859-1', error_bad_lines=False)
dfAntiSocial_YJS.drop(['Unnamed: 0'], axis=1, inplace=True)
sns.lmplot(x='YJS Amount',y='AS Behaviour Amount',data=dfAntiSocial_YJS.corr(),fit_reg=True)

# %%
pd.plotting.scatter_matrix(dfAntiSocial_YJS.corr(), alpha = 1.0, color=['#000000'], s=150, figsize = (8,8), diagonal = 'kde');

# %% [markdown]
# ### Explaining correlation

# %% [markdown]
# ## Below shows the correlation between the amount AntiSocial Behaviour in an area, the amont of Youth Clubs in an area and the amount of people processed by the Youth Justice System in an area

# %%
dfAntiSocial_YC_YJS = pd.read_csv(r'C:\Users\rlark\Documents\Uni\Final Year\CSC3062- Data Visualisation\Final Notebook\DataSets\AntiSocialBehaviour_YouthClubs_YJS.csv', encoding = 'ISO-8859-1', error_bad_lines=False)
dfAntiSocial_YC_YJS.drop(['Unnamed: 0'], axis=1, inplace=True)
sns.lmplot(x='YJS Amount',y='AS Behaviour Amount',data=dfAntiSocial_YC_YJS.corr(),fit_reg=True)

# %%
pd.plotting.scatter_matrix(dfAntiSocial_YC_YJS.corr(), alpha = 1.0, color=['#000000'],s=150, figsize = (12,8), diagonal = 'kde');

# %% [markdown]
# ### Explian Correlation

# %% [markdown]
# ## Below shows the standardised house price by area

# %%
dfStandardisedHousePrice = pd.read_csv(r'C:\Users\rlark\Documents\Uni\Final Year\CSC3062- Data Visualisation\Final Notebook\DataSets\StandardHousePrice.csv', encoding = 'ISO-8859-1', error_bad_lines=False)
dfStandardisedHousePrice.drop(['Unnamed: 0'], axis=1, inplace=True)
lineChartStandardisedPrice = dfStandardisedHousePrice.set_index('Quarter Year').plot(rot=90, kind='line', figsize=(15,8), grid=True
                                ,title="Standardised Price Of Houses")
lineChartStandardisedPrice.set_xlabel("Quarter Year",fontsize=12)
lineChartStandardisedPrice.set_ylabel("Cost GBP",fontsize=12)
# Out:
# Text(0,0.5,u'Cost GBP')

# %% [markdown]
# ## Below shows the average house price by area

# %%
dfAverageHousePrice = pd.read_csv(r'C:\Users\rlark\Documents\Uni\Final Year\CSC3062- Data Visualisation\Final Notebook\DataSets\AverageHousePrice.csv', encoding = 'ISO-8859-1')
dfAverageHousePrice.drop(['Unnamed: 0'], axis=1, inplace=True)
barChartArea = dfAverageHousePrice.set_index('AdministrativeAreaLevel2').plot(rot=90, kind='bar', figsize=(15,8), grid=True
                                ,title="Average House Price By Area", color=['#e80afc'])
barChartArea.set_xlabel("Area",fontsize=12)
barChartArea.set_ylabel("Average Price GBP",fontsize=12)
# Out:
# Text(0,0.5,u'Average Price GBP')

# %% [markdown]
# ## Below shows the correlation between

# %%
dfAntiSocial_HousePrice = pd.read_csv(r'C:\Users\rlark\Documents\Uni\Final Year\CSC3062- Data Visualisation\Final Notebook\DataSets\AntiSocialBehaviour_AverageHousePrice.csv', encoding = 'ISO-8859-1', error_bad_lines=False)
dfAntiSocial_HousePrice.drop(['Unnamed: 0'], axis=1, inplace=True)
sns.lmplot(x='AverageHousePrice',y='AS Behaviour Amount',data=dfAntiSocial_HousePrice.corr(),fit_reg=True)

# %%
pd.plotting.scatter_matrix(dfAntiSocial_HousePrice.corr(), alpha = 1.0, color=['#000000'],s=150, figsize = (8,8), diagonal = 'kde');
